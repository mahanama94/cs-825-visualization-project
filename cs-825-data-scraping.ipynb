# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
country_map = {
    'AUS': 'Australia',
    'PAK': 'Pakistan',
    'SL': 'Sri Lanka',
    'SA': 'South Africa',
    'INDIA': 'India',
    'NZ': 'New Zealand',
    'ENG': 'England',
    'WI': 'West Indies',
    'BDESH': 'Bangladesh',
    'KENYA': 'Kenya',
    'ZIM': 'Zimbabwe'
}

# %% [markdown]
# ## Team Aggregated Statistics

# %% [markdown]
# ### Scraping from ESPN-Cricinfo

# %%
def get_batting_stats():
    def url(i):
        return 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=' + str(i) + ';spanmax1=15+Apr+2021;spanmin1=15+Apr+2006;spanval1=span;template=results;type=team;view=year'
  
    i = 1

    df = None

    while True:
        new_df = pd.read_html(url(i))[2]

        if(len(new_df.index) == 1):
            break
        
        if df is None:
            df = new_df
        else:
            df = df.append(new_df, ignore_index=True)
        
        i= i + 1
        print(i)

    df.to_csv("batting-stats.csv")


    return df

# %%
def get_bowling_stats():
    def url(i):
        return 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=' + str(i) + ';spanmax1=15+Apr+2021;spanmin1=15+Apr+2006;spanval1=span;team_view=bowl;template=results;type=team;view=year'
    i = 1

    df = None

    while True:
        new_df = pd.read_html(url(i))[2]

        if(len(new_df.index) == 1):
            break
        
        if df is None:
            df = new_df
        else:
            df = df.append(new_df, ignore_index=True)
        
        i= i + 1
        print(i)

    df.to_csv("bowling-stats.csv")

    return df

# %%
batting_stats = get_batting_stats()

batting_stats = batting_stats.add_prefix("Batting")

batting_stats.head()
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
#   BattingTeam  BattingMat  ...  BattingYear  BattingUnnamed: 13
# 0   Australia          34  ...         2007                 NaN
# 1    Pakistan          32  ...         2011                 NaN
# 2   Australia          39  ...         2009                 NaN
# 3       India          34  ...         2013                 NaN
# 4       India          34  ...         2011                 NaN
#
# [5 rows x 14 columns]

# %%
bowling_stats = get_bowling_stats()

bowling_stats = bowling_stats.add_prefix("Bowling")

bowling_stats.head()
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
#   BowlingTeam  BowlingMat  ...  BowlingYear  BowlingUnnamed: 13
# 0   Australia          34  ...         2007                 NaN
# 1    Pakistan          32  ...         2011                 NaN
# 2   Australia          39  ...         2009                 NaN
# 3       India          34  ...         2013                 NaN
# 4       India          34  ...         2011                 NaN
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Join Scraped Data

# %%
df = pd.concat([batting_stats, bowling_stats], axis=1, join="inner")

df.head()
# Out:
#   BattingTeam  BattingMat  ...  BowlingYear  BowlingUnnamed: 13
# 0   Australia          34  ...         2007                 NaN
# 1    Pakistan          32  ...         2011                 NaN
# 2   Australia          39  ...         2009                 NaN
# 3       India          34  ...         2013                 NaN
# 4       India          34  ...         2011                 NaN
#
# [5 rows x 28 columns]

# %%
df = df.rename(columns={"BattingTeam": "Team", "BattingMat": "Mat", "BattingLost": "Lost", "BattingWon": "Won", "BattingYear": "Year", "BattingW/L": "W/L"})

df = df.drop(columns=['BattingTied', 'BattingNR', 'BowlingTeam', 'BowlingMat', 'BowlingLost', 'BowlingWon', 'BowlingYear', 'BowlingTied', 'BowlingNR', 'BowlingW/L', 'BattingUnnamed: 13', 'BowlingUnnamed: 13'])

df.head()
# Out:
#         Team  Mat  Won  Lost  ... BowlingRPO  BowlingInns  BowlingHS  BowlingLS
# 0  Australia   34   24     8  ...       5.04           34        350         91
# 1   Pakistan   32   24     7  ...       4.50           31        311         91
# 2  Australia   39   23    14  ...       5.02           38        354        145
# 3      India   34   22    10  ...       5.24           34        359         96
# 4      India   34   21    10  ...       5.17           34        338        174
#
# [5 rows x 16 columns]

# %%
df["BattingLS"] = df["BattingLS"].replace("-", 0).astype(str).astype(int)

df["BowlingLS"] = df["BowlingLS"].replace("-", 0).astype(str).astype(int)

# %%
df = df[df['Team'].isin(country_map.values())]

# %%
df['Team'].unique()
# Out:
# array(['Australia', 'Pakistan', 'India', 'New Zealand', 'Sri Lanka',
#        'South Africa', 'England', 'West Indies', 'Bangladesh', 'Kenya',
#        'Zimbabwe'], dtype=object)

# %%
df.dtypes
# Out:
# Team            object
# Mat              int64
# Won              int64
# Lost             int64
# W/L             object
# BattingAve     float64
# BattingRPO     float64
# BattingInns      int64
# BattingHS        int64
# BattingLS        int64
# Year             int64
# BowlingAve     float64
# BowlingRPO     float64
# BowlingInns      int64
# BowlingHS        int64
# BowlingLS        int64
# dtype: object

# %% [markdown]
# ### Normalize Attributes

# %%
df['NormalizedBattingAve'] = (df['BattingAve'] - df['BattingAve'].min())/(df['BattingAve'].max() - df['BattingAve'].min())
df['NormalizedBattingRPO'] = (df['BattingRPO'] - df['BattingRPO'].min())/(df['BattingRPO'].max() - df['BattingRPO'].min())
df['NormalizedBattingHS'] = (df['BattingHS'] - df['BattingHS'].min())/(df['BattingHS'].max() - df['BattingHS'].min())
df['NormalizedBattingLS'] = (df['BattingLS'] - df['BattingLS'].min())/(df['BattingLS'].max() - df['BattingLS'].min())

# %%
# Normalize and deduct from 1 for bowling figures.
df['NormalizedBowlingAve'] = 1 - (df['BowlingAve'] - df['BowlingAve'].min())/(df['BowlingAve'].max() - df['BowlingAve'].min())
df['NormalizedBowlingRPO'] = 1 - (df['BowlingRPO'] - df['BowlingRPO'].min())/(df['BowlingRPO'].max() - df['BowlingRPO'].min())
df['NormalizedBowlingHS'] = 1 - (df['BowlingHS'] - df['BowlingHS'].min())/(df['BowlingHS'].max() - df['BowlingHS'].min())
df['NormalizedBowlingLS'] = 1 - (df['BowlingLS'] - df['BowlingLS'].min())/(df['BowlingLS'].max() - df['BowlingLS'].min())

# %%
df
# Out:
#              Team  Mat  ...  NormalizedBowlingHS  NormalizedBowlingLS
# 0       Australia   34  ...             0.467857             0.723404
# 1        Pakistan   32  ...             0.607143             0.723404
# 2       Australia   39  ...             0.453571             0.559271
# 3           India   34  ...             0.435714             0.708207
# 4           India   34  ...             0.510714             0.471125
# ..            ...  ...  ...                  ...                  ...
# 247  South Africa    3  ...             0.560714             1.000000
# 253         Kenya    8  ...             0.560714             1.000000
# 255      Zimbabwe    3  ...             0.385714             0.246201
# 262      Zimbabwe    6  ...             0.567857             1.000000
# 263     Sri Lanka    3  ...             0.732143             1.000000
#
# [167 rows x 24 columns]

# %%
df = df.round(2)

# %%
df
# Out:
#              Team  Mat  ...  NormalizedBowlingHS  NormalizedBowlingLS
# 0       Australia   34  ...                 0.47                 0.72
# 1        Pakistan   32  ...                 0.61                 0.72
# 2       Australia   39  ...                 0.45                 0.56
# 3           India   34  ...                 0.44                 0.71
# 4           India   34  ...                 0.51                 0.47
# ..            ...  ...  ...                  ...                  ...
# 247  South Africa    3  ...                 0.56                 1.00
# 253         Kenya    8  ...                 0.56                 1.00
# 255      Zimbabwe    3  ...                 0.39                 0.25
# 262      Zimbabwe    6  ...                 0.57                 1.00
# 263     Sri Lanka    3  ...                 0.73                 1.00
#
# [167 rows x 24 columns]

# %%
df.to_csv("data.csv")

# %%
df['W/L'] = df['W/L'].replace("-", 0).astype(str).astype(float)

# %%
a = df.groupby("Year")["W/L"].mean()
a
# Out:
# Year
# 2006    1.994636
# 2007    1.441455
# 2008    1.880636
# 2009    1.133818
# 2010    1.311364
# 2011    1.338818
# 2012    1.402364
# 2013    1.062000
# 2014    1.253636
# 2015    1.625700
# 2016    1.148200
# 2017    1.489100
# 2018    1.412200
# 2019    1.409000
# 2020    1.035700
# 2021    0.875000
# Name: W/L, dtype: float64

# %%
df['AvgW/L'] = df['Year'].map(lambda x: a[x]).round(2)

df[['Year', 'AvgW/L']]
# Out:
#      Year  AvgW/L
# 0    2007    1.44
# 1    2011    1.34
# 2    2009    1.13
# 3    2013    1.06
# 4    2011    1.34
# ..    ...     ...
# 247  2021    0.88
# 253  2011    1.34
# 255  2012    1.40
# 262  2020    1.04
# 263  2021    0.88
#
# [167 rows x 2 columns]

# %%
df.to_csv('data.csv')

# %%
df['WorldCup'] = False

# %%
df['W/L'].min()
# Out:
# 0.0

# %% [markdown]
# ## Batsman Statistics

# %% [markdown]
# ### SCraping from ESPN-Cricinfo

# %%
def get_batsman_stats():
    
    def url(i):
        return 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=' + str(i) + ';spanmax1=18+Apr+2021;spanmin1=18+Apr+2006;spanval1=span;template=results;type=batting;view=year'
    
    i = 1

    df = None

    while True:
        new_df = pd.read_html(url(i))[2]

        if(len(new_df.index) == 1):
            break
        
        if df is None:
            df = new_df
        else:
            df = df.append(new_df, ignore_index=True)
        
        i= i + 1
        print(i, end='\r')

    df.to_csv("batsman-stats.csv")


    return df

# %%
batsman_stats = get_batsman_stats()

# %%
batsman_stats = pd.read_csv("batsman-stats.csv")

batsman_stats.head(-20)
# Out:
#       Unnamed: 0                     Player  Mat  ...  6s  Year Unnamed: 15
# 0              0            ML Hayden (AUS)   32  ...  35  2007         NaN
# 1              1          RG Sharma (INDIA)   28  ...  36  2019         NaN
# 2              2            MJ Guptill (NZ)   32  ...  42  2015         NaN
# 3              3            V Kohli (INDIA)   26  ...  22  2017         NaN
# 4              4       SR Tendulkar (INDIA)   33  ...  12  2007         NaN
# ...          ...                        ...  ...  ...  ..   ...         ...
# 5335        5335          Jay Odedra (OMAN)    1  ...   -  2020         NaN
# 5336        5336            JB Little (IRE)    2  ...   -  2020         NaN
# 5337        5337      Mohammad Naim (BDESH)    1  ...   -  2020         NaN
# 5338        5338  Mustafizur Rahman (BDESH)    2  ...   -  2020         NaN
# 5339        5339        T Natarajan (INDIA)    1  ...   -  2020         NaN
#
# [5340 rows x 17 columns]

# %% [markdown]
# ### Set Country

# %%
def get_country(data):
    country_map = {
        'AUS': 'Australia',
        'PAK': 'Pakistan',
        'SL': 'Sri Lanka',
        'SA': 'South Africa',
        'INDIA': 'India',
        'NZ': 'New Zealand',
        'ENG': 'England',
        'WI': 'West Indies',
        'BDESH': 'Bangladesh',
        'KENYA': 'Kenya',
        'ZIM': 'Zimbabwe'
    }

    for key in country_map:
        if key in data:
            return country_map[key]
    return 'Other'

batsman_stats['Team'] = batsman_stats['Player'].map(lambda x: get_country(x))

# %%
batsman_stats = batsman_stats[batsman_stats['Team'] != 'Other']

batsman_stats.head()
# Out:
#    Unnamed: 0                Player  Mat  ...  Year Unnamed: 15         Team
# 0           0       ML Hayden (AUS)   32  ...  2007         NaN    Australia
# 1           1     RG Sharma (INDIA)   28  ...  2019         NaN        India
# 2           2       MJ Guptill (NZ)   32  ...  2015         NaN  New Zealand
# 3           3       V Kohli (INDIA)   26  ...  2017         NaN        India
# 4           4  SR Tendulkar (INDIA)   33  ...  2007         NaN        India
#
# [5 rows x 18 columns]

# %%
batsman_stats = batsman_stats.drop(columns=['Unnamed: 0', 'Unnamed: 15'])

# %%
# Character treatment
batsman_stats['HS'] = batsman_stats['HS'].replace("-", 0)

batsman_stats['HS'] = batsman_stats['HS'].map(lambda x: int(str(x).replace("*", "")))

batsman_stats.head()
# Out:
#                  Player  Mat Inns NO  Runs  ...  0   4s  6s  Year         Team
# 0       ML Hayden (AUS)   32   30  3  1601  ...  1  168  35  2007    Australia
# 1     RG Sharma (INDIA)   28   27  1  1490  ...  1  146  36  2019        India
# 2       MJ Guptill (NZ)   32   32  5  1489  ...  3  162  42  2015  New Zealand
# 3       V Kohli (INDIA)   26   26  7  1460  ...  2  136  22  2017        India
# 4  SR Tendulkar (INDIA)   33   32  2  1425  ...  3  192  12  2007        India
#
# [5 rows x 16 columns]

# %%
batsman_stats.to_csv('batsman-stats.csv')

# %% [markdown]
# ## Bowler Stats

# %% [markdown]
# #### Scrape from ESPN-Cricinfo

# %%
def get_bowler_stats():
    
    def url(i):
        return 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=' + str(i) +';spanmax1=19+Apr+2021;spanmin1=19+Apr+2006;spanval1=span;template=results;type=bowling;view=year'
        # return 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;page=' + str(i) + ';spanmax1=18+Apr+2021;spanmin1=18+Apr+2006;spanval1=span;template=results;type=batting;view=year'
    
    i = 1

    df = None

    while True:
        new_df = pd.read_html(url(i))[2]

        if(len(new_df.index) == 1):
            break
        
        if df is None:
            df = new_df
        else:
            df = df.append(new_df, ignore_index=True)
        
        i= i + 1
        
    print(str(i) +  " Pages scraped")

    df.to_csv("bowler-stats.csv")


    return df

# %%
bowler_stats = get_bowler_stats()
# Out:
# 109 Pages scraped

# %%
bowler_stats['Team'] = bowler_stats['Player'].map(lambda x: get_country(x))

bowler_stats
# Out:
#                       Player  Mat Inns  ...  Year Unnamed: 14          Team
# 0          Saeed Ajmal (PAK)   33   33  ...  2013         NaN      Pakistan
# 1          RA Jadeja (INDIA)   34   34  ...  2013         NaN         India
# 2          Junaid Khan (PAK)   28   28  ...  2013         NaN      Pakistan
# 3            BAW Mendis (SL)   18   17  ...  2008         NaN     Sri Lanka
# 4            SL Malinga (SL)   24   23  ...  2011         NaN     Sri Lanka
# ...                      ...  ...  ...  ...   ...         ...           ...
# 5355         LJ Tucker (IRE)    5    -  ...  2021         NaN         Other
# 5356  HE van der Dussen (SA)    2    -  ...  2021         NaN  South Africa
# 5357        K Verreynne (SA)    1    -  ...  2021         NaN  South Africa
# 5358           WA Young (NZ)    2    -  ...  2021         NaN   New Zealand
# 5359       Zawar Farid (UAE)    2    -  ...  2021         NaN         Other
#
# [5360 rows x 16 columns]

# %%
bowler_stats = bowler_stats.drop(columns=['Unnamed: 14'])

bowler_stats
# Out:
#                       Player  Mat Inns  Overs  ...  4  5  Year          Team
# 0          Saeed Ajmal (PAK)   33   33  306.3  ...  2  1  2013      Pakistan
# 1          RA Jadeja (INDIA)   34   34  303.3  ...  1  1  2013         India
# 2          Junaid Khan (PAK)   28   28  228.3  ...  1  0  2013      Pakistan
# 3            BAW Mendis (SL)   18   17  135.3  ...  3  3  2008     Sri Lanka
# 4            SL Malinga (SL)   24   23  192.1  ...  0  3  2011     Sri Lanka
# ...                      ...  ...  ...    ...  ... .. ..   ...           ...
# 5355         LJ Tucker (IRE)    5    -      -  ...  -  -  2021         Other
# 5356  HE van der Dussen (SA)    2    -      -  ...  -  -  2021  South Africa
# 5357        K Verreynne (SA)    1    -      -  ...  -  -  2021  South Africa
# 5358           WA Young (NZ)    2    -      -  ...  -  -  2021   New Zealand
# 5359       Zawar Farid (UAE)    2    -      -  ...  -  -  2021         Other
#
# [5360 rows x 15 columns]

# %%
bowler_stats = bowler_stats[bowler_stats['Team'] != 'Other']

bowler_stats
# Out:
#                       Player  Mat Inns  Overs  ...  4  5  Year          Team
# 0          Saeed Ajmal (PAK)   33   33  306.3  ...  2  1  2013      Pakistan
# 1          RA Jadeja (INDIA)   34   34  303.3  ...  1  1  2013         India
# 2          Junaid Khan (PAK)   28   28  228.3  ...  1  0  2013      Pakistan
# 3            BAW Mendis (SL)   18   17  135.3  ...  3  3  2008     Sri Lanka
# 4            SL Malinga (SL)   24   23  192.1  ...  0  3  2011     Sri Lanka
# ...                      ...  ...  ...    ...  ... .. ..   ...           ...
# 5353     Tamim Iqbal (BDESH)    6    -      -  ...  -  -  2021    Bangladesh
# 5354        LRPL Taylor (NZ)    1    -      -  ...  -  -  2021   New Zealand
# 5356  HE van der Dussen (SA)    2    -      -  ...  -  -  2021  South Africa
# 5357        K Verreynne (SA)    1    -      -  ...  -  -  2021  South Africa
# 5358           WA Young (NZ)    2    -      -  ...  -  -  2021   New Zealand
#
# [3802 rows x 15 columns]

# %%
bowler_stats = bowler_stats.drop(bowler_stats.index[bowler_stats['Econ'] == '-'])

bowler_stats.to_csv("bowler-stats.csv")

# %%
bowler_stats.head()
# Out:
#               Player  Mat Inns  Overs Mdns  ...    SR  4  5  Year       Team
# 0  Saeed Ajmal (PAK)   33   33  306.3   15  ...  29.6  2  1  2013   Pakistan
# 1  RA Jadeja (INDIA)   34   34  303.3   22  ...    35  1  1  2013      India
# 2  Junaid Khan (PAK)   28   28  228.3   17  ...  26.3  1  0  2013   Pakistan
# 3    BAW Mendis (SL)   18   17  135.3   13  ...  16.9  3  3  2008  Sri Lanka
# 4    SL Malinga (SL)   24   23  192.1   12  ...    24  0  3  2011  Sri Lanka
#
# [5 rows x 15 columns]

# %%
bowler_stats['Team'].unique()
# Out:
# array(['Pakistan', 'India', 'Sri Lanka', 'Australia', 'Bangladesh',
#        'South Africa', 'Zimbabwe', 'New Zealand', 'England',
#        'West Indies', 'Kenya'], dtype=object)

# %%
batsman_stats['Ave'] = batsman_stats['HS'].replace("-", 0)

batsman_stats['HS'] = batsman_stats['HS'].map(lambda x: int(str(x).replace("*", "")))

batsman_stats.head()
# Out:
#                  Player  Mat Inns NO  Runs  ...  0   4s  6s  Year         Team
# 0       ML Hayden (AUS)   32   30  3  1601  ...  1  168  35  2007    Australia
# 1     RG Sharma (INDIA)   28   27  1  1490  ...  1  146  36  2019        India
# 2       MJ Guptill (NZ)   32   32  5  1489  ...  3  162  42  2015  New Zealand
# 3       V Kohli (INDIA)   26   26  7  1460  ...  2  136  22  2017        India
# 4  SR Tendulkar (INDIA)   33   32  2  1425  ...  3  192  12  2007        India
#
# [5 rows x 16 columns]
